# %%
import numpy as np 
import matplotlib.pyplot as plt 

reward_hist_array = np.zeros((10,2000))

path = '../trained_models/new_movie_with_int_061923/'


def smooth(data, num_pts, mode):

    box = np.ones(num_pts)/num_pts
    y_smooth = np.convolve(data, box, mode=mode)

    return y_smooth

for i in range(0,10):
    
    s = np.load(path+str(i)+"_success_history.npy")
    print(np.mean(s[0:10]))
    print(np.mean(s[0:400]))
    s = smooth(s, num_pts = 400, mode = 'valid')
    print(i)
    print(len(s))
    print(np.sum(s))
    print(np.mean(s[6000:]))
    print(np.max(s))
    #print(np.sum(s[0:150]))
    
    x = np.arange(len(s))  
    plt.plot(x,s)
    plt.ylim([0,0.3])
    #plt.axvline(lines, c='r')

    plt.show()
# Out:
# 0.0
# 0.0
# 0
# 28128
# 2363.1675000000005
# 0.08954593727404195
# 0.20750000000000002
# 0.0
# 0.0025
# 1
# 33140
# 2999.5775000000003
# 0.09737214443625646
# 0.2625
# 0.0
# 0.0
# 2
# 33156
# 2971.7075000000004
# 0.10372017233760497
# 0.24000000000000002
# 0.0
# 0.0
# 3
# 31245
# 2568.66
# 0.0883115468409586
# 0.19
# 0.0
# 0.0
# 4
# 38575
# 1373.2275
# 0.0311894858019954
# 0.16249999999999998
# 0.0
# 0.0025
# 5
# 32888
# 2536.3775
# 0.07846827581077061
# 0.16999999999999998
# 0.0
# 0.0
# 6
# 30194
# 3433.1725
# 0.13222606844672233
# 0.2225
# 0.0
# 0.0
# 7
# 35134
# 1923.21
# 0.06064426443330817
# 0.15000000000000002
# 0.0
# 0.0
# 8
# 33570
# 1410.6675
# 0.04775272034820457
# 0.11500000000000002
# 0.0
# 0.0
# 9
# 32657
# 1312.825
# 0.03928367783321455
# 0.1525
